# %%
# !pip install fastapi nest-asyncio pyngrok uvicorn scikit-learn flask
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (0.115.12)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Collecting pyngrok
#   Downloading pyngrok-7.2.7-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (0.34.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: flask in /usr/local/lib/python3.11/dist-packages (3.1.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi) (2.11.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (4.13.2)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.1)
# Downloading pyngrok-7.2.7-py3-none-any.whl (23 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.7

# %%
# !pip install gradio sentence-transformers numpy
# Out:
# Collecting gradio
#   Downloading gradio-5.29.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.9.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.10.0 (from gradio)
#   Downloading gradio_client-1.10.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.30.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (11.2.1)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.11.4)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.11.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.15.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.13.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.0->gradio) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.0->gradio) (15.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.4.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.4.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-5.29.0-py3-none-any.whl (54.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 MB 18.5 MB/s eta 0:00:00
# Downloading gradio_client-1.10.0-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.9/322.9 kB 29.6 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 8.5 MB/s eta 0:00:00
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.11.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 120.3 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.3 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 117.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.2 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.7 MB/s eta 0:00:00
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, uvicorn, tomlkit, semantic-version, ruff, python-multipart, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, groovy, ffmpy, aiofiles, starlette, nvidia-cusparse-cu12, nvidia-cudnn-cu12, safehttpx, nvidia-cusolver-cu12, gradio-client, fastapi, gradio
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed aiofiles-24.1.0 fastapi-0.115.12 ffmpy-0.5.0 gradio-5.29.0 gradio-client-1.10.0 groovy-0.1.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pydub-0.25.1 python-multipart-0.0.20 ruff-0.11.8 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.46.2 tomlkit-0.13.2 uvicorn-0.34.2

# %%
import requests
from bs4 import BeautifulSoup
import time

BASE_URL = "https://shl.com"
PAGE_STEP = 12
MAX_WORKERS = 8

def extract_data_from_page(soup):
    data = []
    rows = soup.select("tr[data-course-id], tr[data-entity-id]")
    for row in rows:
        course_id = row.get("data-course-id")
        entity_id = row.get("data-entity-id")
        item_id = course_id or entity_id
        item_type = "course" if course_id else "entity"

        tds = row.find_all("td")
        if len(tds) < 4:
            continue

        link_tag = tds[0].select_one("a[href]")
        link = BASE_URL + link_tag["href"] if link_tag else None
        name = link_tag.text.strip() if link_tag else None

        # Safe span check using class list
        def has_yes_icon(td):
            span = td.find("span")
            return span and "-yes" in span.get("class", [])

        is_remote = has_yes_icon(tds[1])
        is_adaptive = has_yes_icon(tds[2])
        keys = [k.text.strip() for k in tds[3].select(".product-catalogue__key")]

        data.append({
            "type": item_type,
            "id": item_id,
            "name": name,
            "link": link,
            "remote": is_remote,
            "adaptive_or_irt": is_adaptive,
            "keys": keys
        })
    return data



def scrape_all_pages_by_type(content_type):
    results = []
    start = 0
    while True:
        url = f"{BASE_URL}/products/product-catalog/?start={start}&type={content_type}"
        print(f"Scraping page: {url}")
        response = requests.get(url)
        soup = BeautifulSoup(response.text, "html.parser")

        page_data = extract_data_from_page(soup)
        if not page_data:
            break  # No more data

        results.extend(page_data)

        # Check if there's a next page
        next_button = soup.select_one("li.-next a")
        if not next_button:
            break

        start += PAGE_STEP
        time.sleep(1)

    return results

if __name__ == "__main__":
    all_data = []
    for content_type in [1, 2]:  # Adjust this if there are more types
        data = scrape_all_pages_by_type(content_type)
        all_data.extend(data)

    for item in all_data:
        print(item)
# Out:
# Scraping page: https://shl.com/products/product-catalog/?start=0&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=12&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=24&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=36&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=48&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=60&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=72&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=84&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=96&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=108&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=120&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=132&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=144&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=156&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=168&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=180&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=192&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=204&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=216&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=228&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=240&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=252&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=264&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=276&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=288&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=300&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=312&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=324&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=336&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=348&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=360&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=372&type=1
# Scraping page: https://shl.com/products/product-catalog/?start=0&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=12&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=24&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=36&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=48&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=60&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=72&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=84&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=96&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=108&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=120&type=2
# Scraping page: https://shl.com/products/product-catalog/?start=132&type=2
# {'type': 'course', 'id': '57', 'name': 'Account Manager Solution', 'link': 'https://shl.com/products/product-catalog/view/account-manager-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['C', 'P', 'A', 'B']}
# {'type': 'course', 'id': '144', 'name': 'Administrative Professional - Short Form', 'link': 'https://shl.com/products/product-catalog/view/administrative-professional-short-form/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'K', 'P']}
# {'type': 'course', 'id': '71', 'name': 'Agency Manager Solution', 'link': 'https://shl.com/products/product-catalog/view/agency-manager-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P', 'S']}
# {'type': 'course', 'id': '521', 'name': 'Apprentice + 8.0 Job Focused Assessment', 'link': 'https://shl.com/products/product-catalog/view/apprentice-8-0-job-focused-assessment-4261/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'P']}
# {'type': 'course', 'id': '520', 'name': 'Apprentice 8.0 Job Focused Assessment', 'link': 'https://shl.com/products/product-catalog/view/apprentice-8-0-job-focused-assessment/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'P']}
# {'type': 'course', 'id': '41', 'name': 'Bank Administrative Assistant - Short Form', 'link': 'https://shl.com/products/product-catalog/view/bank-administrative-assistant-short-form/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'K', 'P']}
# {'type': 'course', 'id': '31', 'name': 'Bank Collections Agent - Short Form', 'link': 'https://shl.com/products/product-catalog/view/bank-collections-agent-short-form/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '42', 'name': 'Bank Operations Supervisor - Short Form', 'link': 'https://shl.com/products/product-catalog/view/bank-operations-supervisor-short-form/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P', 'S']}
# {'type': 'course', 'id': '102', 'name': 'Bilingual Spanish Reservation Agent Solution', 'link': 'https://shl.com/products/product-catalog/view/bilingual-spanish-reservation-agent-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['B', 'P', 'S', 'A']}
# {'type': 'course', 'id': '83', 'name': 'Bookkeeping, Accounting, Auditing Clerk Short Form', 'link': 'https://shl.com/products/product-catalog/view/bookkeeping-accounting-auditing-clerk-short-form/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['P', 'S', 'K', 'B', 'A']}
# {'type': 'course', 'id': '30', 'name': 'Branch Manager - Short Form', 'link': 'https://shl.com/products/product-catalog/view/branch-manager-short-form/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '45', 'name': 'Cashier Solution', 'link': 'https://shl.com/products/product-catalog/view/cashier-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['B', 'A', 'P']}
# {'type': 'entity', 'id': '4302', 'name': 'Global Skills Development Report', 'link': 'https://shl.com/products/product-catalog/view/global-skills-development-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'E', 'B', 'C', 'D', 'P']}
# {'type': 'entity', 'id': '3827', 'name': '.NET Framework 4.5', 'link': 'https://shl.com/products/product-catalog/view/net-framework-4-5/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '4094', 'name': '.NET MVC (New)', 'link': 'https://shl.com/products/product-catalog/view/net-mvc-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4099', 'name': '.NET MVVM (New)', 'link': 'https://shl.com/products/product-catalog/view/net-mvvm-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4018', 'name': '.NET WCF (New)', 'link': 'https://shl.com/products/product-catalog/view/net-wcf-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4016', 'name': '.NET WPF (New)', 'link': 'https://shl.com/products/product-catalog/view/net-wpf-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4165', 'name': '.NET XAML (New)', 'link': 'https://shl.com/products/product-catalog/view/net-xaml-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4178', 'name': 'Accounts Payable (New)', 'link': 'https://shl.com/products/product-catalog/view/accounts-payable-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4187', 'name': 'Accounts Payable Simulation (New)', 'link': 'https://shl.com/products/product-catalog/view/accounts-payable-simulation-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '4179', 'name': 'Accounts Receivable (New)', 'link': 'https://shl.com/products/product-catalog/view/accounts-receivable-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4188', 'name': 'Accounts Receivable Simulation (New)', 'link': 'https://shl.com/products/product-catalog/view/accounts-receivable-simulation-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '4168', 'name': 'ADO.NET (New)', 'link': 'https://shl.com/products/product-catalog/view/ado-net-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4019', 'name': 'Adobe Experience Manager (New)', 'link': 'https://shl.com/products/product-catalog/view/adobe-experience-manager-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3778', 'name': 'Adobe Photoshop CC', 'link': 'https://shl.com/products/product-catalog/view/adobe-photoshop-cc/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '4069', 'name': 'Aeronautical Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/aeronautical-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4004', 'name': 'Aerospace Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/aerospace-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4223', 'name': 'Agile Software Development', 'link': 'https://shl.com/products/product-catalog/view/agile-software-development/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4159', 'name': 'Agile Testing (New)', 'link': 'https://shl.com/products/product-catalog/view/agile-testing-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4311', 'name': 'AI Skills', 'link': 'https://shl.com/products/product-catalog/view/ai-skills/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P']}
# {'type': 'entity', 'id': '4028', 'name': 'Amazon Web Services (AWS) Development (New)', 'link': 'https://shl.com/products/product-catalog/view/amazon-web-services-aws-development-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4160', 'name': 'Android Development (New)', 'link': 'https://shl.com/products/product-catalog/view/android-development-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4153', 'name': 'Angular 6 (New)', 'link': 'https://shl.com/products/product-catalog/view/angular-6-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4021', 'name': 'AngularJS (New)', 'link': 'https://shl.com/products/product-catalog/view/angularjs-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4030', 'name': 'Apache Hadoop (New)', 'link': 'https://shl.com/products/product-catalog/view/apache-hadoop-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4011', 'name': 'Apache Hadoop Extensions (New)', 'link': 'https://shl.com/products/product-catalog/view/apache-hadoop-extensions-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4073', 'name': 'Apache HBase (New)', 'link': 'https://shl.com/products/product-catalog/view/apache-hbase-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4075', 'name': 'Apache Hive (New)', 'link': 'https://shl.com/products/product-catalog/view/apache-hive-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4022', 'name': 'Apache Kafka (New)', 'link': 'https://shl.com/products/product-catalog/view/apache-kafka-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4115', 'name': 'Apache Pig (New)', 'link': 'https://shl.com/products/product-catalog/view/apache-pig-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4023', 'name': 'Apache Spark (New)', 'link': 'https://shl.com/products/product-catalog/view/apache-spark-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4017', 'name': 'ASP .NET with C# (New)', 'link': 'https://shl.com/products/product-catalog/view/asp-net-with-c-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3786', 'name': 'ASP.NET 4.5', 'link': 'https://shl.com/products/product-catalog/view/asp-net-4-5/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '4219', 'name': 'Assessment and Development Center Exercises', 'link': 'https://shl.com/products/product-catalog/view/assessment-and-development-center-exercises/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['E']}
# {'type': 'entity', 'id': '3980', 'name': 'Automata - Fix (New)', 'link': 'https://shl.com/products/product-catalog/view/automata-fix-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '3981', 'name': 'Automata - SQL (New)', 'link': 'https://shl.com/products/product-catalog/view/automata-sql-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '3984', 'name': 'Automata (New)', 'link': 'https://shl.com/products/product-catalog/view/automata-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '3982', 'name': 'Automata Data Science (New)', 'link': 'https://shl.com/products/product-catalog/view/automata-data-science-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '3983', 'name': 'Automata Data Science Pro (New)', 'link': 'https://shl.com/products/product-catalog/view/automata-data-science-pro-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '4222', 'name': 'Automata Front End', 'link': 'https://shl.com/products/product-catalog/view/automata-front-end/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '3985', 'name': 'Automata Pro (New)', 'link': 'https://shl.com/products/product-catalog/view/automata-pro-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '4229', 'name': 'Automata Selenium', 'link': 'https://shl.com/products/product-catalog/view/automata-selenium/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '4026', 'name': 'Automation Anywhere RPA Development (New)', 'link': 'https://shl.com/products/product-catalog/view/automation-anywhere-rpa-development-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4025', 'name': 'Automotive Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/automotive-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3988', 'name': 'Basic Biology (New)', 'link': 'https://shl.com/products/product-catalog/view/basic-biology-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4206', 'name': 'Basic Computer Literacy (Windows 10) (New)', 'link': 'https://shl.com/products/product-catalog/view/basic-computer-literacy-windows-10-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S', 'K']}
# {'type': 'entity', 'id': '4149', 'name': 'Basic Statistics (New)', 'link': 'https://shl.com/products/product-catalog/view/basic-statistics-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4161', 'name': 'Biochemistry (New)', 'link': 'https://shl.com/products/product-catalog/view/biochemistry-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4036', 'name': 'Biotech Lab Techniques (New)', 'link': 'https://shl.com/products/product-catalog/view/biotech-lab-techniques-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4037', 'name': 'BizTalk (New)', 'link': 'https://shl.com/products/product-catalog/view/biztalk-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '244', 'name': 'Business Communication (adaptive)', 'link': 'https://shl.com/products/product-catalog/view/business-communication-adaptive/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '536', 'name': 'Business Communications', 'link': 'https://shl.com/products/product-catalog/view/business-communications/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4038', 'name': 'C Programming (New)', 'link': 'https://shl.com/products/product-catalog/view/c-programming-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4039', 'name': 'C# Programming (New)', 'link': 'https://shl.com/products/product-catalog/view/c-programming-new-4039/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4122', 'name': 'C++ Programming (New)', 'link': 'https://shl.com/products/product-catalog/view/c-programming-new-4122/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4077', 'name': 'Cardiology and Diabetes Management (New)', 'link': 'https://shl.com/products/product-catalog/view/cardiology-and-diabetes-management-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4044', 'name': 'Ceramic Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/ceramic-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4012', 'name': 'Chemical Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/chemical-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4024', 'name': 'Cisco AppDynamics (New)', 'link': 'https://shl.com/products/product-catalog/view/cisco-appdynamics-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4150', 'name': 'Civil Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/civil-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4045', 'name': 'Cloud Computing (New)', 'link': 'https://shl.com/products/product-catalog/view/cloud-computing-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4046', 'name': 'COBOL Programming (New)', 'link': 'https://shl.com/products/product-catalog/view/cobol-programming-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4104', 'name': 'Computer Science (New)', 'link': 'https://shl.com/products/product-catalog/view/computer-science-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4189', 'name': 'Contact Center Call Simulation (New)', 'link': 'https://shl.com/products/product-catalog/view/contact-center-call-simulation-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '4296', 'name': 'Conversational Multichat Simulation', 'link': 'https://shl.com/products/product-catalog/view/conversational-multichat-simulation/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '4034', 'name': 'Core Java (Advanced Level) (New)', 'link': 'https://shl.com/products/product-catalog/view/core-java-advanced-level-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4032', 'name': 'Core Java (Entry Level) (New)', 'link': 'https://shl.com/products/product-catalog/view/core-java-entry-level-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3458', 'name': 'Count Out The Money', 'link': 'https://shl.com/products/product-catalog/view/count-out-the-money/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K', 'S']}
# {'type': 'entity', 'id': '4052', 'name': 'CSS3 (New)', 'link': 'https://shl.com/products/product-catalog/view/css3-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4050', 'name': 'Culinary Skills (New)', 'link': 'https://shl.com/products/product-catalog/view/culinary-skills-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3933', 'name': 'Customer Service Phone Simulation', 'link': 'https://shl.com/products/product-catalog/view/customer-service-phone-simulation/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'S']}
# {'type': 'entity', 'id': '3931', 'name': 'Customer Service Phone Solution', 'link': 'https://shl.com/products/product-catalog/view/customer-service-phone-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'P', 'S']}
# {'type': 'entity', 'id': '4053', 'name': 'Cyber Risk (New)', 'link': 'https://shl.com/products/product-catalog/view/cyber-risk-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4186', 'name': 'Data Entry (New)', 'link': 'https://shl.com/products/product-catalog/view/data-entry-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'entity', 'id': '778', 'name': 'Data Entry Alphanumeric Split Screen - US', 'link': 'https://shl.com/products/product-catalog/view/data-entry-alphanumeric-split-screen-us/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '779', 'name': 'Data Entry Numeric Split Screen - US', 'link': 'https://shl.com/products/product-catalog/view/data-entry-numeric-split-screen-us/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '785', 'name': 'Data Entry Ten Key Split Screen', 'link': 'https://shl.com/products/product-catalog/view/data-entry-ten-key-split-screen/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4013', 'name': 'Data Science (New)', 'link': 'https://shl.com/products/product-catalog/view/data-science-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '56', 'name': 'Data Warehousing Concepts', 'link': 'https://shl.com/products/product-catalog/view/data-warehousing-concepts/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '731', 'name': 'Dependability and Safety Instrument (DSI)', 'link': 'https://shl.com/products/product-catalog/view/dependability-and-safety-instrument-dsi/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P']}
# {'type': 'entity', 'id': '4162', 'name': 'Dermatology (New)', 'link': 'https://shl.com/products/product-catalog/view/dermatology-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4101', 'name': 'Desktop Support (New)', 'link': 'https://shl.com/products/product-catalog/view/desktop-support-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4003', 'name': 'Digital Advertising (New)', 'link': 'https://shl.com/products/product-catalog/view/digital-advertising-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4221', 'name': 'Digital Readiness Development Report - IC', 'link': 'https://shl.com/products/product-catalog/view/digital-readiness-development-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P']}
# {'type': 'entity', 'id': '4239', 'name': 'Digital Readiness Development Report - Manager', 'link': 'https://shl.com/products/product-catalog/view/digital-readiness-development-report-manager/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P']}
# {'type': 'entity', 'id': '4059', 'name': 'Docker (New)', 'link': 'https://shl.com/products/product-catalog/view/docker-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4060', 'name': 'Dojo (New)', 'link': 'https://shl.com/products/product-catalog/view/dojo-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4062', 'name': 'Drupal (New)', 'link': 'https://shl.com/products/product-catalog/view/drupal-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '1102', 'name': 'DSI v1.1 Interpretation Report', 'link': 'https://shl.com/products/product-catalog/view/dsi-v1-1-interpretation-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P']}
# {'type': 'entity', 'id': '4148', 'name': 'Econometrics (New)', 'link': 'https://shl.com/products/product-catalog/view/econometrics-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4009', 'name': 'Economics (New)', 'link': 'https://shl.com/products/product-catalog/view/economics-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4001', 'name': 'Electrical and Electronics Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/electrical-and-electronics-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4031', 'name': 'Electrical Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/electrical-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4002', 'name': 'Electronics & Telecommunications Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/electronics-and-telecommunications-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4000', 'name': 'Electronics and Embedded Systems Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/electronics-and-embedded-systems-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4139', 'name': 'Electronics and Semiconductor Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/electronics-and-semiconductor-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4180', 'name': 'English Comprehension (New)', 'link': 'https://shl.com/products/product-catalog/view/english-comprehension-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4063', 'name': 'Enterprise Java Beans (New)', 'link': 'https://shl.com/products/product-catalog/view/enterprise-java-beans-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3856', 'name': 'Enterprise Leadership Report 1.0', 'link': 'https://shl.com/products/product-catalog/view/enterprise-leadership-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P']}
# {'type': 'entity', 'id': '4287', 'name': 'Enterprise Leadership Report 2.0', 'link': 'https://shl.com/products/product-catalog/view/enterprise-leadership-report-2-0/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P']}
# {'type': 'entity', 'id': '3934', 'name': 'Entry Level Cashier Solution', 'link': 'https://shl.com/products/product-catalog/view/entry-level-cashier-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'P']}
# {'type': 'entity', 'id': '3939', 'name': 'Entry Level Customer Serv-Retail & Contact Center', 'link': 'https://shl.com/products/product-catalog/view/entry-level-customer-serv-retail-and-contact-center/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P', 'C']}
# {'type': 'entity', 'id': '3935', 'name': 'Entry Level Customer Service (General) Solution', 'link': 'https://shl.com/products/product-catalog/view/entry-level-customer-service-general-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'P']}
# {'type': 'entity', 'id': '3936', 'name': 'Entry Level Hotel Front Desk Solution', 'link': 'https://shl.com/products/product-catalog/view/entry-level-hotel-front-desk-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'P']}
# {'type': 'entity', 'id': '3937', 'name': 'Entry Level Sales Solution', 'link': 'https://shl.com/products/product-catalog/view/entry-level-sales-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'P']}
# {'type': 'entity', 'id': '3938', 'name': 'Entry Level Technical Support Solution', 'link': 'https://shl.com/products/product-catalog/view/entry-level-technical-support-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P', 'C']}
# {'type': 'entity', 'id': '4065', 'name': 'ETL Testing (New)', 'link': 'https://shl.com/products/product-catalog/view/etl-testing-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '743', 'name': 'Executive Scenarios', 'link': 'https://shl.com/products/product-catalog/view/executive-scenarios/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '3849', 'name': 'Executive Scenarios Narrative Report', 'link': 'https://shl.com/products/product-catalog/view/executive-scenarios-narrative-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '3899', 'name': 'Executive Scenarios Profile Report', 'link': 'https://shl.com/products/product-catalog/view/executive-scenarios-profile-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '4127', 'name': 'ExpressJS (New)', 'link': 'https://shl.com/products/product-catalog/view/expressjs-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '380', 'name': 'Filing - Names (R1)', 'link': 'https://shl.com/products/product-catalog/view/filing-names-r1/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '381', 'name': 'Filing - Numbers', 'link': 'https://shl.com/products/product-catalog/view/filing-numbers/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3992', 'name': 'Financial Accounting (New)', 'link': 'https://shl.com/products/product-catalog/view/financial-accounting-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4083', 'name': 'Financial and Banking Services (New)', 'link': 'https://shl.com/products/product-catalog/view/financial-and-banking-services-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4067', 'name': 'Fire Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/fire-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '382', 'name': 'Following Instructions v1 - UK (R1)', 'link': 'https://shl.com/products/product-catalog/view/following-instructions-v1-uk-r1/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '383', 'name': 'Following Instructions v1 - US (R2)', 'link': 'https://shl.com/products/product-catalog/view/following-instructions-v1-us-r2/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4090', 'name': 'Food and Beverage Services (New)', 'link': 'https://shl.com/products/product-catalog/view/food-and-beverage-services-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4071', 'name': 'Food Science (New)', 'link': 'https://shl.com/products/product-catalog/view/food-science-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4072', 'name': 'Front Office Management (New)', 'link': 'https://shl.com/products/product-catalog/view/front-office-management-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4113', 'name': 'Fundamentals of Chemistry (New)', 'link': 'https://shl.com/products/product-catalog/view/fundamentals-of-chemistry-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4043', 'name': 'Fundamentals of Physics (New)', 'link': 'https://shl.com/products/product-catalog/view/fundamentals-of-physics-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4048', 'name': 'General Diseases (New)', 'link': 'https://shl.com/products/product-catalog/view/general-diseases-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4125', 'name': 'Geoinformatics Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/geoinformatics-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4066', 'name': 'Geoscience Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/geoscience-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4078', 'name': 'GIT (New)', 'link': 'https://shl.com/products/product-catalog/view/git-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4301', 'name': 'Global Skills Assessment', 'link': 'https://shl.com/products/product-catalog/view/global-skills-assessment/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'K']}
# {'type': 'entity', 'id': '741', 'name': 'Graduate Scenarios', 'link': 'https://shl.com/products/product-catalog/view/graduate-scenarios/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '3900', 'name': 'Graduate Scenarios Narrative Report', 'link': 'https://shl.com/products/product-catalog/view/graduate-scenarios-narrative-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '3901', 'name': 'Graduate Scenarios Profile Report', 'link': 'https://shl.com/products/product-catalog/view/graduate-scenarios-profile-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '4074', 'name': 'Hibernate (New)', 'link': 'https://shl.com/products/product-catalog/view/hibernate-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '331', 'name': 'HIPAA (Security)', 'link': 'https://shl.com/products/product-catalog/view/hipaa-security/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '3845', 'name': 'HiPo Assessment Report 1.0', 'link': 'https://shl.com/products/product-catalog/view/hipo-assessment-report-1-0/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'P']}
# {'type': 'entity', 'id': '4284', 'name': 'HiPo Assessment Report 2.0', 'link': 'https://shl.com/products/product-catalog/view/hipo-assessment-report-2-0/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'P']}
# {'type': 'entity', 'id': '4285', 'name': 'HiPo Unlocking Potential Report 2.0', 'link': 'https://shl.com/products/product-catalog/view/hipo-unlocking-potential-report-2-0/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C']}
# {'type': 'entity', 'id': '4076', 'name': 'Housekeeping (New)', 'link': 'https://shl.com/products/product-catalog/view/housekeeping-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4080', 'name': 'HTML/CSS (New)', 'link': 'https://shl.com/products/product-catalog/view/htmlcss-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4081', 'name': 'HTML5 (New)', 'link': 'https://shl.com/products/product-catalog/view/html5-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3999', 'name': 'Human Resources (New)', 'link': 'https://shl.com/products/product-catalog/view/human-resources-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4169', 'name': 'IBM DataStage (New)', 'link': 'https://shl.com/products/product-catalog/view/ibm-datastage-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4155', 'name': 'IBM Sterling Order Management System (New)', 'link': 'https://shl.com/products/product-catalog/view/ibm-sterling-order-management-system-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4005', 'name': 'Industrial Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/industrial-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4054', 'name': 'Informatica (Architecture) (New)', 'link': 'https://shl.com/products/product-catalog/view/informatica-architecture-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4055', 'name': 'Informatica (Developer) (New)', 'link': 'https://shl.com/products/product-catalog/view/informatica-developer-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4007', 'name': 'Instrumentation Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/instrumentation-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '249', 'name': 'Interpersonal Communications', 'link': 'https://shl.com/products/product-catalog/view/interpersonal-communications/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '333', 'name': 'Interviewing and Hiring Concepts (U.S.)', 'link': 'https://shl.com/products/product-catalog/view/interviewing-and-hiring-concepts-u-s/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '4102', 'name': 'iOS Development (New)', 'link': 'https://shl.com/products/product-catalog/view/ios-development-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4040', 'name': 'ITIL (IT Infrastructure Library) (New)', 'link': 'https://shl.com/products/product-catalog/view/itil-it-infrastructure-library-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '88', 'name': 'Java 2 Platform Enterprise Edition 1.4 Fundamental', 'link': 'https://shl.com/products/product-catalog/view/java-2-platform-enterprise-edition-1-4-fundamental/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '4084', 'name': 'Java 8 (New)', 'link': 'https://shl.com/products/product-catalog/view/java-8-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4158', 'name': 'Java Design Patterns (New)', 'link': 'https://shl.com/products/product-catalog/view/java-design-patterns-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4056', 'name': 'Java Frameworks (New)', 'link': 'https://shl.com/products/product-catalog/view/java-frameworks-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3809', 'name': 'Java Platform Enterprise Edition 7 (Java EE 7)', 'link': 'https://shl.com/products/product-catalog/view/java-platform-enterprise-edition-7-java-ee-7/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '4033', 'name': 'Java Web Services (New)', 'link': 'https://shl.com/products/product-catalog/view/java-web-services-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3989', 'name': 'JavaScript (New)', 'link': 'https://shl.com/products/product-catalog/view/javascript-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4086', 'name': 'Jenkins (New)', 'link': 'https://shl.com/products/product-catalog/view/jenkins-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4085', 'name': 'Job Control Language (New)', 'link': 'https://shl.com/products/product-catalog/view/job-control-language-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4087', 'name': 'jQuery (New)', 'link': 'https://shl.com/products/product-catalog/view/jquery-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4152', 'name': 'Kubernetes (New)', 'link': 'https://shl.com/products/product-catalog/view/kubernetes-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3990', 'name': 'Linux Administration (New)', 'link': 'https://shl.com/products/product-catalog/view/linux-administration-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4299', 'name': 'Linux Operating System', 'link': 'https://shl.com/products/product-catalog/view/linux-operating-system/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '205', 'name': 'Linux Programming (General)', 'link': 'https://shl.com/products/product-catalog/view/linux-programming-general/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '4170', 'name': 'Load Runner (New)', 'link': 'https://shl.com/products/product-catalog/view/load-runner-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '742', 'name': 'Management Scenarios', 'link': 'https://shl.com/products/product-catalog/view/management-scenarios/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '3903', 'name': 'Managerial Scenarios Candidate Report', 'link': 'https://shl.com/products/product-catalog/view/managerial-scenarios-candidate-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '3902', 'name': 'Managerial Scenarios Narrative Report', 'link': 'https://shl.com/products/product-catalog/view/managerial-scenarios-narrative-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '3904', 'name': 'Managerial Scenarios Profile Report', 'link': 'https://shl.com/products/product-catalog/view/managerial-scenarios-profile-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'entity', 'id': '4157', 'name': 'Manual Testing (New)', 'link': 'https://shl.com/products/product-catalog/view/manual-testing-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4291', 'name': 'Manufac. & Indust. - Mechanical & Vigilance 8.0', 'link': 'https://shl.com/products/product-catalog/view/mechanical-and-vigilance-focus-8-0/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'P']}
# {'type': 'entity', 'id': '4293', 'name': 'Manufac. & Indust. - Safety & Dependability 8.0', 'link': 'https://shl.com/products/product-catalog/view/safety-and-dependability-focus-8-0/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P']}
# {'type': 'entity', 'id': '4295', 'name': 'Manufacturing & Industrial - Essential Focus 8.0', 'link': 'https://shl.com/products/product-catalog/view/essential-focus-8-0/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P']}
# {'type': 'entity', 'id': '4292', 'name': 'Manufacturing & Industrial - Mechanical Focus 8.0', 'link': 'https://shl.com/products/product-catalog/view/mechanical-focus-8-0/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'P']}
# {'type': 'entity', 'id': '4294', 'name': 'Manufacturing & Industrial - Vigilance Focus 8.0', 'link': 'https://shl.com/products/product-catalog/view/vigilance-focus-8-0/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'P']}
# {'type': 'entity', 'id': '4008', 'name': 'Marketing (New)', 'link': 'https://shl.com/products/product-catalog/view/marketing-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4089', 'name': 'Maven (New)', 'link': 'https://shl.com/products/product-catalog/view/maven-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4006', 'name': 'Mechanical Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/mechanical-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4176', 'name': 'Mechatronics Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/mechatronics-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4058', 'name': 'Medical Terminology (New)', 'link': 'https://shl.com/products/product-catalog/view/medical-terminology-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4119', 'name': 'Metallurgical Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/metallurgical-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '3951', 'name': 'MFS 360 Enterprise Leadership Report', 'link': 'https://shl.com/products/product-catalog/view/mfs-360-enterprise-leadership-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['D']}
# {'type': 'entity', 'id': '3950', 'name': 'MFS 360 UCF Group Report', 'link': 'https://shl.com/products/product-catalog/view/mfs-360-ucf-group-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['D']}
# {'type': 'entity', 'id': '3949', 'name': 'MFS 360 UCF Performance Potential Dev Tips Report', 'link': 'https://shl.com/products/product-catalog/view/mfs-360-ucf-performance-potential-dev-tips-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['D']}
# {'type': 'entity', 'id': '3948', 'name': 'MFS 360 UCF Standard Report', 'link': 'https://shl.com/products/product-catalog/view/mfs-360-ucf-standard-report/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['D']}
# {'type': 'entity', 'id': '4027', 'name': 'Micro Focus Unified Functional Testing (New)', 'link': 'https://shl.com/products/product-catalog/view/micro-focus-unified-functional-testing-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4091', 'name': 'Microservices (New)', 'link': 'https://shl.com/products/product-catalog/view/microservices-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4092', 'name': 'Microsoft Dynamics Development (New)', 'link': 'https://shl.com/products/product-catalog/view/microsoft-dynamics-development-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4208', 'name': 'Microsoft Excel 365 - Essentials (New)', 'link': 'https://shl.com/products/product-catalog/view/microsoft-excel-365-essentials-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K', 'S']}
# {'type': 'entity', 'id': '4207', 'name': 'Microsoft Excel 365 (New)', 'link': 'https://shl.com/products/product-catalog/view/microsoft-excel-365-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K', 'S']}
# {'type': 'entity', 'id': '3785', 'name': 'Microsoft Outlook 2013 (adaptive)', 'link': 'https://shl.com/products/product-catalog/view/microsoft-outlook-2013-adaptive/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '4212', 'name': 'Microsoft PowerPoint 365 - Essentials (New)', 'link': 'https://shl.com/products/product-catalog/view/microsoft-powerpoint-365-essentials-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K', 'S']}
# {'type': 'entity', 'id': '3789', 'name': 'Microsoft SQL Server 2014 Programming', 'link': 'https://shl.com/products/product-catalog/view/microsoft-sql-server-2014-programming/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '3807', 'name': 'Microsoft Windows Server 2012 Administration', 'link': 'https://shl.com/products/product-catalog/view/microsoft-windows-server-2012-administration/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['K']}
# {'type': 'entity', 'id': '4211', 'name': 'Microsoft Word 365 - Essentials (New)', 'link': 'https://shl.com/products/product-catalog/view/microsoft-word-365-essentials-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K', 'S']}
# {'type': 'entity', 'id': '4210', 'name': 'Microsoft Word 365 (New)', 'link': 'https://shl.com/products/product-catalog/view/microsoft-word-365-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S', 'K']}
# {'type': 'entity', 'id': '4047', 'name': 'Mineral Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/mineral-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# {'type': 'entity', 'id': '4093', 'name': 'Mining Engineering (New)', 'link': 'https://shl.com/products/product-catalog/view/mining-engineering-new/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['K']}
# ...
# {'type': 'course', 'id': '84', 'name': 'Manager - Short Form', 'link': 'https://shl.com/products/product-catalog/view/manager-short-form/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'K', 'P', 'S']}
# {'type': 'course', 'id': '235', 'name': 'Manager + 7.0 Solution', 'link': 'https://shl.com/products/product-catalog/view/manager-7-0-solution-3955/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'C']}
# {'type': 'course', 'id': '505', 'name': 'Manager + 7.1 (Americas)', 'link': 'https://shl.com/products/product-catalog/view/manager-7-1-solution-4242/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['B', 'C', 'P']}
# {'type': 'course', 'id': '531', 'name': 'Manager + 7.1 (International)', 'link': 'https://shl.com/products/product-catalog/view/manager-7-1-%28international%29/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['B', 'C', 'P']}
# {'type': 'course', 'id': '234', 'name': 'Manager 7.0 Solution', 'link': 'https://shl.com/products/product-catalog/view/manager-7-0-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C']}
# {'type': 'course', 'id': '535', 'name': 'Manager 7.1 (Americas)', 'link': 'https://shl.com/products/product-catalog/view/manager-7-1-%28americas%29/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C', 'P']}
# {'type': 'course', 'id': '504', 'name': 'Manager 7.1 (International)', 'link': 'https://shl.com/products/product-catalog/view/manager-7-1-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C', 'P']}
# {'type': 'course', 'id': '568', 'name': 'Manager 8.0 JFA', 'link': 'https://shl.com/products/product-catalog/view/manager-8-0-jfa/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'K', 'P']}
# {'type': 'course', 'id': '569', 'name': 'Manager 8.0+ JFA', 'link': 'https://shl.com/products/product-catalog/view/manager-8-0-jfa-4310/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'K', 'P']}
# {'type': 'course', 'id': '185', 'name': 'Manufacturing Production Team Member', 'link': 'https://shl.com/products/product-catalog/view/manufacturing-production-team-member/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B']}
# {'type': 'course', 'id': '186', 'name': 'Manufacturing Skilled Maintenance Worker', 'link': 'https://shl.com/products/product-catalog/view/manufacturing-skilled-maintenance-worker/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B']}
# {'type': 'course', 'id': '139', 'name': 'Network Engineer/Analyst Solution', 'link': 'https://shl.com/products/product-catalog/view/network-engineeranalyst-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['P', 'S', 'K', 'B', 'A']}
# {'type': 'course', 'id': '70', 'name': 'Nurse Leader Solution', 'link': 'https://shl.com/products/product-catalog/view/nurse-leader-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['S', 'A', 'B', 'P']}
# {'type': 'course', 'id': '69', 'name': 'Nurse Solution', 'link': 'https://shl.com/products/product-catalog/view/nurse-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['P', 'A', 'B']}
# {'type': 'course', 'id': '61', 'name': 'Nursing Assistant Solution', 'link': 'https://shl.com/products/product-catalog/view/nursing-assistant-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '40', 'name': 'Personal Banker - Short Form', 'link': 'https://shl.com/products/product-catalog/view/personal-banker-short-form/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'K', 'P', 'S']}
# {'type': 'course', 'id': '33', 'name': 'Phone Banker - Short Form', 'link': 'https://shl.com/products/product-catalog/view/phone-banker-short-form/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '90', 'name': 'Prep/Line Cook Solution', 'link': 'https://shl.com/products/product-catalog/view/prepline-cook-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '238', 'name': 'Professional + 7.0 Solution', 'link': 'https://shl.com/products/product-catalog/view/professional-7-0-solution-3958/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'C']}
# {'type': 'course', 'id': '539', 'name': 'Professional + 7.1 (Americas)', 'link': 'https://shl.com/products/product-catalog/view/professional-7-1-%28americas%29/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['B', 'C', 'P']}
# {'type': 'course', 'id': '507', 'name': 'Professional + 7.1 (International)', 'link': 'https://shl.com/products/product-catalog/view/professional-7-1-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['B', 'C', 'P']}
# {'type': 'course', 'id': '237', 'name': 'Professional 7.0 Solution', 'link': 'https://shl.com/products/product-catalog/view/professional-7-0-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C']}
# {'type': 'course', 'id': '510', 'name': 'Professional 7.1 (International)', 'link': 'https://shl.com/products/product-catalog/view/professional-7-1-solution-4247/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'B']}
# {'type': 'course', 'id': '564', 'name': 'Professional 8.0 JFA', 'link': 'https://shl.com/products/product-catalog/view/professional-8-0-jfa/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'K', 'P']}
# {'type': 'course', 'id': '34', 'name': 'Professional/Individual Contributor - Short Form', 'link': 'https://shl.com/products/product-catalog/view/professionalindividual-contributor-short-form/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P', 'S']}
# {'type': 'course', 'id': '85', 'name': 'Project Manager - Short Form', 'link': 'https://shl.com/products/product-catalog/view/project-manager-short-form/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P', 'S']}
# {'type': 'course', 'id': '43', 'name': 'Proof Operator - Processing Specialist -Short Form', 'link': 'https://shl.com/products/product-catalog/view/proof-operator-processing-specialist-short-form/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['S']}
# {'type': 'course', 'id': '101', 'name': 'Reservation Agent Solution', 'link': 'https://shl.com/products/product-catalog/view/reservation-agent-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'P', 'S', 'B']}
# {'type': 'course', 'id': '91', 'name': 'Restaurant Manager Solution', 'link': 'https://shl.com/products/product-catalog/view/restaurant-manager-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P', 'S']}
# {'type': 'course', 'id': '92', 'name': 'Restaurant Supervisor Solution', 'link': 'https://shl.com/products/product-catalog/view/restaurant-supervisor-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '47', 'name': 'Retail Consultant Solution', 'link': 'https://shl.com/products/product-catalog/view/retail-consultant-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '50', 'name': 'Retail Manager w/ Sales Solution', 'link': 'https://shl.com/products/product-catalog/view/retail-manager-w-sales-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '44', 'name': 'Retail Sales Associate Solution', 'link': 'https://shl.com/products/product-catalog/view/retail-sales-associate-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '82', 'name': 'Sales Director Solution', 'link': 'https://shl.com/products/product-catalog/view/sales-director-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '140', 'name': 'Sales Engineer Solution', 'link': 'https://shl.com/products/product-catalog/view/sales-engineer-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'K', 'P', 'S']}
# {'type': 'course', 'id': '29', 'name': 'Sales Manager Solution', 'link': 'https://shl.com/products/product-catalog/view/sales-manager-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '236', 'name': 'Sales Professional 7.0 Solution', 'link': 'https://shl.com/products/product-catalog/view/sales-professional-7-0-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'B']}
# {'type': 'course', 'id': '537', 'name': 'Sales Professional 7.1 (Americas)', 'link': 'https://shl.com/products/product-catalog/view/sales-professional-7-1-%28americas%29/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C']}
# {'type': 'course', 'id': '54', 'name': 'Sales Professional Solution', 'link': 'https://shl.com/products/product-catalog/view/sales-professional-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '53', 'name': 'Sales Representative Solution', 'link': 'https://shl.com/products/product-catalog/view/sales-representative-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '56', 'name': 'Sales Supervisor Solution', 'link': 'https://shl.com/products/product-catalog/view/sales-supervisor-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '52', 'name': 'Sales Support Specialist Solution', 'link': 'https://shl.com/products/product-catalog/view/sales-support-specialist-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '81', 'name': 'Senior Insurance Agent Solution', 'link': 'https://shl.com/products/product-catalog/view/senior-insurance-agent-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '55', 'name': 'Senior Sales Professional Solution', 'link': 'https://shl.com/products/product-catalog/view/senior-sales-professional-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '93', 'name': 'Server Solution', 'link': 'https://shl.com/products/product-catalog/view/server-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['B', 'A', 'P']}
# {'type': 'course', 'id': '97', 'name': 'Service Associate Solution', 'link': 'https://shl.com/products/product-catalog/view/service-associate-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '98', 'name': 'Service Supervisor Solution', 'link': 'https://shl.com/products/product-catalog/view/service-supervisor-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '46', 'name': 'Stock Clerk Solution', 'link': 'https://shl.com/products/product-catalog/view/stock-clerk-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '233', 'name': 'Store Manager 7.0 Solution', 'link': 'https://shl.com/products/product-catalog/view/store-manager-7-0-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C']}
# {'type': 'course', 'id': '530', 'name': 'Store Manager 7.1 (Americas)', 'link': 'https://shl.com/products/product-catalog/view/store-manager-7-1-%28americas%29/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C']}
# {'type': 'course', 'id': '532', 'name': 'Store Manager 7.1 (International)', 'link': 'https://shl.com/products/product-catalog/view/store-manager-7-1-%28international%29/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'B']}
# {'type': 'course', 'id': '48', 'name': 'Store Manager Solution', 'link': 'https://shl.com/products/product-catalog/view/store-manager-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '38', 'name': 'Supervisor - Short Form', 'link': 'https://shl.com/products/product-catalog/view/supervisor-short-form/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['S']}
# {'type': 'course', 'id': '232', 'name': 'Supervisor 7.0 Solution', 'link': 'https://shl.com/products/product-catalog/view/supervisor-7-0-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C']}
# {'type': 'course', 'id': '518', 'name': 'Supervisor 7.1 (Americas)', 'link': 'https://shl.com/products/product-catalog/view/supervisor-7-1-%28americas%29/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C', 'P']}
# {'type': 'course', 'id': '517', 'name': 'Supervisor 7.1 (International)', 'link': 'https://shl.com/products/product-catalog/view/supervisor-7-1-%28international%29/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['P', 'C', 'B']}
# {'type': 'course', 'id': '99', 'name': 'Support Associate Solution', 'link': 'https://shl.com/products/product-catalog/view/support-associate-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '100', 'name': 'Support Supervisor Solution', 'link': 'https://shl.com/products/product-catalog/view/support-supervisor-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'P', 'S', 'B']}
# {'type': 'course', 'id': '49', 'name': 'Technical Sales Associate Solution', 'link': 'https://shl.com/products/product-catalog/view/technical-sales-associate-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '62', 'name': 'Technician/Technologist Solution', 'link': 'https://shl.com/products/product-catalog/view/techniciantechnologist-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '492', 'name': 'Technology Professional 8.0 Job Focused Assessment', 'link': 'https://shl.com/products/product-catalog/view/technology-professional-8-0-job-focused-assessment/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['C', 'P']}
# {'type': 'course', 'id': '63', 'name': 'Telenurse Solution', 'link': 'https://shl.com/products/product-catalog/view/telenurse-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'P']}
# {'type': 'course', 'id': '482', 'name': 'Teller 7.0', 'link': 'https://shl.com/products/product-catalog/view/teller-7-0/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['B', 'K', 'P', 'S']}
# {'type': 'course', 'id': '39', 'name': 'Teller with Sales - Short Form', 'link': 'https://shl.com/products/product-catalog/view/teller-with-sales-short-form/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['A', 'B', 'K', 'P', 'S']}
# {'type': 'course', 'id': '64', 'name': 'Transcriptionist Solution', 'link': 'https://shl.com/products/product-catalog/view/transcriptionist-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['A', 'B', 'K', 'P']}
# {'type': 'course', 'id': '244', 'name': 'Workplace Safety - Individual 7.0 Solution', 'link': 'https://shl.com/products/product-catalog/view/workplace-safety-individual-7-0-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'course', 'id': '511', 'name': 'Workplace Safety - Individual 7.1 (Americas)', 'link': 'https://shl.com/products/product-catalog/view/workplace-safety-individual-7-1-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'course', 'id': '245', 'name': 'Workplace Safety - Team 7.0 Solution', 'link': 'https://shl.com/products/product-catalog/view/workplace-safety-team-7-0-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B']}
# {'type': 'course', 'id': '538', 'name': 'Workplace Safety - Team 7.1 (Americas)', 'link': 'https://shl.com/products/product-catalog/view/workplace-safety-team-7-1-%28americas%29/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C', 'P']}
# {'type': 'course', 'id': '506', 'name': 'Workplace Safety - Team 7.1 (International)', 'link': 'https://shl.com/products/product-catalog/view/workplace-safety-team-7-1-solution/', 'remote': True, 'adaptive_or_irt': None, 'keys': ['B', 'C', 'P']}
# {'type': 'course', 'id': '195', 'name': 'Workplace Safety Solution', 'link': 'https://shl.com/products/product-catalog/view/workplace-safety-solution/', 'remote': True, 'adaptive_or_irt': True, 'keys': ['B', 'P']}

# %%
import json

# Assuming your scraped data is stored in `all_data`
data_to_save = all_data  # or `results` or whatever you named it

with open("shl_data_basic.json", "w", encoding="utf-8") as f:
    json.dump(data_to_save, f, ensure_ascii=False, indent=2)

print("[✓] Scraped data saved to 'shl_data_basic.json'")
# Out:
# [✓] Scraped data saved to 'shl_data_basic.json'

# %%
import requests
from bs4 import BeautifulSoup
import json
from concurrent.futures import ThreadPoolExecutor, as_completed

BASE_URL = "https://shl.com"

def extract_detail_fields(item):
    detail_url = item.get("link")
    if not detail_url:
        return item

    if detail_url.startswith("/"):
        detail_url = BASE_URL + detail_url

    try:
        response = requests.get(detail_url, timeout=10)
        soup = BeautifulSoup(response.text, "html.parser")

        detail = {
            "description": None,
            "job_levels": None,
            "languages": None,
            "assessment_length": None
        }

        rows = soup.select("div.product-catalogue-training-calendar__row.typ")
        for row in rows:
            heading = row.find("h4")
            value = row.find("p")
            if not heading or not value:
                continue

            key = heading.get_text(strip=True).lower()
            val = value.get_text(strip=True)

            if "description" in key:
                detail["description"] = val
            elif "job level" in key:
                detail["job_levels"] = val
            elif "language" in key:
                detail["languages"] = val
            elif "assessment length" in key or "completion time" in key:
                detail["assessment_length"] = val

        item.update(detail)
        return item

    except Exception as e:
        print(f"[ERROR] {item.get('name')} - {e}")
        return item  # Return at least the base item even if enrichment fails

if __name__ == "__main__":
    with open("shl_data_basic.json", "r") as f:
        data = json.load(f)

    enriched_data = []

    # Use ThreadPoolExecutor to speed up requests
    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = [executor.submit(extract_detail_fields, item) for item in data]

        for i, future in enumerate(as_completed(futures), 1):
            result = future.result()
            enriched_data.append(result)
            print(f"[{i}/{len(data)}] Processed: {result.get('name')}")

    with open("shl_data_enriched.json", "w") as f:
        json.dump(enriched_data, f, indent=2)

    print("\n✅ Done! Saved enriched data to `shl_data_enriched.json`.")
# Out:
# [1/542] Processed: Account Manager Solution
# [2/542] Processed: Bank Collections Agent - Short Form
# [3/542] Processed: Bank Operations Supervisor - Short Form
# [4/542] Processed: Apprentice 8.0 Job Focused Assessment
# [5/542] Processed: Agency Manager Solution
# [6/542] Processed: Administrative Professional - Short Form
# [7/542] Processed: Apprentice + 8.0 Job Focused Assessment
# [8/542] Processed: Bilingual Spanish Reservation Agent Solution
# [9/542] Processed: Bank Administrative Assistant - Short Form
# [10/542] Processed: Bookkeeping, Accounting, Auditing Clerk Short Form
# [11/542] Processed: .NET MVC (New)
# [12/542] Processed: .NET MVVM (New)
# [13/542] Processed: .NET XAML (New)
# [14/542] Processed: Branch Manager - Short Form
# [15/542] Processed: Cashier Solution
# [16/542] Processed: Global Skills Development Report
# [17/542] Processed: .NET WCF (New)
# [18/542] Processed: Accounts Payable (New)
# [19/542] Processed: .NET WPF (New)
# [20/542] Processed: .NET Framework 4.5
# [21/542] Processed: Accounts Payable Simulation (New)
# [22/542] Processed: ADO.NET (New)
# [23/542] Processed: Adobe Experience Manager (New)
# [24/542] Processed: Accounts Receivable Simulation (New)
# [25/542] Processed: Agile Testing (New)
# [26/542] Processed: Aeronautical Engineering (New)
# [27/542] Processed: Accounts Receivable (New)
# [28/542] Processed: Aerospace Engineering (New)
# [29/542] Processed: Adobe Photoshop CC
# [30/542] Processed: Agile Software Development
# [31/542] Processed: Amazon Web Services (AWS) Development (New)
# [32/542] Processed: Angular 6 (New)
# [33/542] Processed: AngularJS (New)
# [34/542] Processed: Apache Hive (New)
# [35/542] Processed: Android Development (New)
# [36/542] Processed: AI Skills
# [37/542] Processed: Apache HBase (New)
# [38/542] Processed: Apache Hadoop (New)
# [39/542] Processed: Apache Hadoop Extensions (New)
# [40/542] Processed: Apache Spark (New)
# [41/542] Processed: Apache Kafka (New)
# [42/542] Processed: Apache Pig (New)
# [43/542] Processed: ASP .NET with C# (New)
# [44/542] Processed: Assessment and Development Center Exercises
# [45/542] Processed: Automata (New)
# [46/542] Processed: Automata - SQL (New)
# [47/542] Processed: ASP.NET 4.5
# [48/542] Processed: Automata - Fix (New)
# [49/542] Processed: Automata Data Science Pro (New)
# [50/542] Processed: Automata Data Science (New)
# [51/542] Processed: Automata Pro (New)
# [52/542] Processed: Automata Front End
# [53/542] Processed: Automata Selenium
# [54/542] Processed: Automation Anywhere RPA Development (New)
# [55/542] Processed: Basic Biology (New)
# [56/542] Processed: Basic Computer Literacy (Windows 10) (New)
# [57/542] Processed: Basic Statistics (New)
# [387/542] Processed: Written Spanish
# [388/542] Processed: Administrative Professional - Short Form
# [389/542] Processed: 360° Multi-Rater Feedback System (MFS)
# [390/542] Processed: Account Manager Solution
# [391/542] Processed: Agency Manager Solution
# [392/542] Processed: Apprentice + 8.0 Job Focused Assessment
# [393/542] Processed: 360 Digital Report
# [394/542] Processed: Apprentice 8.0 Job Focused Assessment
# [395/542] Processed: Bank Administrative Assistant - Short Form
# [396/542] Processed: Bank Operations Supervisor - Short Form
# [397/542] Processed: Bank Collections Agent - Short Form
# [398/542] Processed: Bilingual Spanish Reservation Agent Solution
# [399/542] Processed: Branch Manager - Short Form
# [400/542] Processed: Bookkeeping, Accounting, Auditing Clerk Short Form
# [401/542] Processed: Cashier Solution
# [402/542] Processed: Global Skills Development Report
# [403/542] Processed: .NET MVC (New)
# [404/542] Processed: .NET WCF (New)
# [405/542] Processed: .NET MVVM (New)
# [406/542] Processed: .NET Framework 4.5
# [407/542] Processed: .NET WPF (New)
# [408/542] Processed: .NET XAML (New)
# [409/542] Processed: Accounts Payable (New)
# [410/542] Processed: Accounts Receivable (New)
# [411/542] Processed: Accounts Payable Simulation (New)
# [412/542] Processed: Accounts Receivable Simulation (New)
# [413/542] Processed: ADO.NET (New)
# [414/542] Processed: Claims/Operations Supervisor Solution
# [415/542] Processed: Contact Center Customer Service + 8.0
# [416/542] Processed: Contact Center Sales & Service + 8.0
# [417/542] Processed: Contact Center Customer Service 8.0
# [418/542] Processed: Contact Center Sales & Service 8.0
# [419/542] Processed: Contact Center Manager - Short Form
# [420/542] Processed: Contact Center Team Lead/Coach - Short Form
# [421/542] Processed: Contact Centre Agent Solution - UK
# [422/542] Processed: Customer Service - Short Form
# [423/542] Processed: Customer Service - Short Form - UK
# [424/542] Processed: Customer Service with Sales - Short Form
# [425/542] Processed: Director - Short Form
# [426/542] Processed: District/Regional Manager Solution
# [427/542] Processed: Entry Level Cashier 7.1 (Americas)
# [428/542] Processed: Entry Level Cashier 7.1 (International)
# [429/542] Processed: Entry level Sales 7.1 (Americas)
# [430/542] Processed: Entry Level Customer Service 7.1 (South Africa)
# [431/542] Processed: Entry Level Customer Service 7.1 (International)
# [432/542] Processed: Entry Level Sales Sift Out 7.1
# [433/542] Processed: Entry Level Customer Service 7.1 (Americas)
# [434/542] Processed: Entry level Sales 7.1 (International)
# [435/542] Processed: Event Sales Manager Solution
# [436/542] Processed: Executive - Short Form
# [437/542] Processed: Financial Services Representative Solution
# [438/542] Processed: Gaming Associate Solution
# [439/542] Processed: Financial Professional - Short Form
# [440/542] Processed: Front Desk Associate Solution
# [441/542] Processed: Gaming Manager Solution
# [442/542] Processed: General Entry Level - All Industries 7.0 Solution
# [443/542] Processed: General Entry Level - All Industries 7.1(Americas)
# [444/542] Processed: General Entry Level - All Industries 7.1 Solution
# [445/542] Processed: General Entry Level – Data Entry 7.0 Solution
# [446/542] Processed: Graduate + 8.0 Job Focused Assessment
# [447/542] Processed: Graduate 7.1 Job Focused Assessment
# [448/542] Processed: Healthcare Call Center Agent Solution
# [514/542] Processed: Senior Insurance Agent Solution
# [515/542] Processed: Senior Sales Professional Solution
# [516/542] Processed: Server Solution
# [517/542] Processed: Service Associate Solution
# [518/542] Processed: Stock Clerk Solution
# [519/542] Processed: Service Supervisor Solution
# [520/542] Processed: Store Manager 7.1 (Americas)
# [521/542] Processed: Store Manager 7.0 Solution
# [522/542] Processed: Store Manager Solution
# [523/542] Processed: Store Manager 7.1 (International)
# [524/542] Processed: Supervisor - Short Form
# [525/542] Processed: Supervisor 7.1 (Americas)
# [526/542] Processed: Supervisor 7.0 Solution
# [527/542] Processed: Supervisor 7.1 (International)
# [528/542] Processed: Support Associate Solution
# [529/542] Processed: Support Supervisor Solution
# [530/542] Processed: Telenurse Solution
# [531/542] Processed: Technology Professional 8.0 Job Focused Assessment
# [532/542] Processed: Technical Sales Associate Solution
# [533/542] Processed: Teller 7.0
# [534/542] Processed: Technician/Technologist Solution
# [535/542] Processed: Teller with Sales - Short Form
# [536/542] Processed: Transcriptionist Solution
# [537/542] Processed: Workplace Safety - Individual 7.0 Solution
# [538/542] Processed: Workplace Safety - Team 7.0 Solution
# [539/542] Processed: Workplace Safety - Team 7.1 (Americas)
# [540/542] Processed: Workplace Safety - Team 7.1 (International)
# [541/542] Processed: Workplace Safety - Individual 7.1 (Americas)
# [542/542] Processed: Workplace Safety Solution
#
# ✅ Done! Saved enriched data to `shl_data_enriched.json`.

# %%
import json
import pandas as pd
import os

# Get the current working directory
current_directory = os.getcwd()

# Construct the correct file path
file_path = os.path.join(current_directory, "shl_data_enriched.json")


# Load the cleaned JSON data
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Convert the JSON data to a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to an Excel file in the current directory
excel_file = os.path.join(current_directory, "shl_data_enriched.xlsx")
df.to_excel(excel_file, index=False)

print(f"Data successfully saved to {excel_file}")
# Out:
# Data successfully saved to /content/shl_data_enriched.xlsx

# %%
import json
import pandas as pd
import os

# Get the current working directory
current_directory = os.getcwd()

# Construct the correct file path
file_path = os.path.join(current_directory, "shl_data_basic.json")


# Load the cleaned JSON data
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Convert the JSON data to a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to an Excel file in the current directory
excel_file = os.path.join(current_directory, "shl_data_basic.xlsx")
df.to_excel(excel_file, index=False)

print(f"Data successfully saved to {excel_file}")
# Out:
# Data successfully saved to /content/shl_data_basic.xlsx

# %%
import json
import re
import numpy as np
import pandas as pd
import gradio as gr
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# ----------------------
# CONSTANTS
# ----------------------
KEY_MAPPING = {
    "A": "Ability & Aptitude",
    "B": "Biodata & Situational Judgement",
    "C": "Competencies",
    "D": "Development & 360",
    "E": "Assessment Exercises",
    "K": "Knowledge & Skills",
    "P": "Personality & Behavior",
    "S": "Simulations"
}

# ----------------------
# LOAD & PREPROCESS DATA
# ----------------------

def load_and_prepare_data(filepath):
    with open(filepath, "r", encoding="utf-8") as f:
        data = json.load(f)

    for item in data:
        item["embedding_text"] = f"{item['name']} {item['description']}"

        try:
            item["duration"] = int(item.get("assessment_length", "0").split('=')[-1].strip())
        except:
            item["duration"] = 0

        item["adaptive_support"] = "Yes" if item.get("adaptive_or_irt") else "No"
        item["remote_support"] = "Yes" if item.get("remote") else "No"

        keys = item.get("keys", [])
        item["test_type"] = [KEY_MAPPING.get(k, k) for k in keys]

        item["job_level"] = (item.get("job_levels") or "").strip().rstrip(",") if isinstance(item.get("job_levels"), str) else item.get("job_levels")
        item["languages"] = (item.get("languages") or "").strip().rstrip(",") if isinstance(item.get("languages"), str) else item.get("languages")

    return data

# Load and preprocess the SHL assessments
assessments = load_and_prepare_data("/content/shl_data_enriched.json")

# ----------------------
# EMBEDDINGS
# ----------------------

model = SentenceTransformer('sentence-transformers/msmarco-MiniLM-L12-cos-v5')
corpus_embeddings = embedding_model.encode([a["embedding_text"] for a in assessments])

# ----------------------
# RECOMMENDER
# ----------------------

def extract_duration_from_query(query):
    match = re.search(r'(\d+)\s*minutes?', query.lower())
    return int(match.group(1)) if match else None

def normalize_name(name):
    return name.lower().strip()

def recommend_assessments(user_query, max_duration=None):
    query_embedding = model.encode(user_query, convert_to_tensor=False)
    similarities = cosine_similarity([query_embedding], corpus_embeddings)[0]

    top_indices = np.argsort(similarities)[::-1]
    results = []

    for i in top_indices:
        a = assessments[i]
        if max_duration is not None and a.get("duration", 0) > max_duration:
            continue

        results.append({
            "Assessment Name": a.get('name', ''),
            "Job Level": a.get("job_level", ''),
            "Duration (min)": a.get("duration", 0),
            "Remote Testing": a.get("remote_support", ''),
            "Adaptive/IRT": a.get("adaptive_support", ''),
            "Test Type(s)": ', '.join(a.get("test_type", [])),
            "Languages": a.get("languages", ''),
            "Description": (a.get("description", '')[:200] + "...") if a.get("description") else ''
        })

        if len(results) == 10:
            break

    return pd.DataFrame(results)

# ----------------------
# ACCURACY METRICS
# ----------------------

def calculate_recall_at_k(relevant_assessments, recommended_assessments, k=3):
    recommended_set = set(recommended_assessments[:k])
    relevant_set = set(relevant_assessments)
    return len(recommended_set.intersection(relevant_set)) / len(relevant_set) if len(relevant_set) > 0 else 0

def calculate_map_at_k(relevant_assessments, recommended_assessments, k=3):
    ap_k = 0
    num_relevant = 0
    for i in range(min(k, len(recommended_assessments))):
        if recommended_assessments[i] in relevant_assessments:
            num_relevant += 1
            ap_k += num_relevant / (i + 1)
    return ap_k / min(k, len(relevant_assessments)) if len(relevant_assessments) > 0 else 0

def evaluate_model(test_queries, ground_truth, k=3):
    recalls_at_k = []
    map_at_k = []

    for query, relevant in zip(test_queries, ground_truth):
        max_duration = extract_duration_from_query(query)
        recommended_df = recommend_assessments(query, max_duration=max_duration)

        recommended_names = [normalize_name(a) for a in recommended_df["Assessment Name"].tolist()]
        relevant_names = [normalize_name(r) for r in relevant]

        recalls_at_k.append(calculate_recall_at_k(relevant_names, recommended_names, k))
        map_at_k.append(calculate_map_at_k(relevant_names, recommended_names, k))

    return np.mean(recalls_at_k), np.mean(map_at_k)

# ----------------------
# MAIN TESTING BLOCK
# ----------------------

if __name__ == "__main__":
    test_queries = [
        "I am hiring for Java developers who can also collaborate effectively with my business teams. Looking for an assessment(s) that can be completed in 40 minutes.",
        "I want to hire new graduates for a sales role in my company, the budget is for about an hour for each test. Give me some options.",
        "I am looking for a COO for my company in China and I want to see if they are culturally a right fit for our company. Suggest me an assessment that they can complete in about an hour.",
        "Content Writer required, expert in English and SEO.",
        "Find me 1 hour long assesment for the below job at SHL Job Description Join a community that is shaping the future of work! SHL, People Science. People Answers. Are you a seasoned QA Engineer with a flair for innovation? Are you ready to shape the future of talent assessment and empower organizations to unlock their full potential? If so, we want you to be a part of the SHL Team! As a QA Engineer, you will be involved in creating and implementing software solutions that contribute to the development of our groundbreaking products. An excellent benefit package is offered in a culture where career development, with ongoing manager guidance, collaboration, flexibility, diversity, and inclusivity are all intrinsic to our culture. There is a huge investment in SHL currently so there’s no better time to become a part of something transformational. What You Will Be Doing Getting involved in engineering quality assurance and providing inputs when required. Create and develop test plans for various forms of testing. Conducts and/or participates in formal and informal test case reviews. Develop and initiate functional tests and regression tests. Rolling out improvements for testing and quality processes. Essential What we are looking for from you: Development experience – Java or JavaScript, CSS, HTML (Automation) Selenium WebDriver and page object design pattern (Automation) SQL server knowledge Test case management experience. Manual Testing Desirable Knowledge the basic concepts of testing Strong solution-finding experience Strong verbal and written communicator. Get In Touch Find out how this one-off opportunity can help you achieve your career goals by making an application to our knowledgeable and friendly Talent Acquisition team. Choose a new path with SHL. #CareersAtSHL #SHLHiringTalent #TechnologyJobs #QualityAssuranceJobs #CareerOpportunities #JobOpportunities About Us We unlock the possibilities of businesses through the power of people, science and technology. We started this industry of people insight more than 40 years ago and continue to lead the market with powerhouse product launches, ground-breaking science and business transformation. When you inspire and transform people’s lives, you will experience the greatest business outcomes possible. SHL’s products insights, experiences, and services can help achieve growth at scale. What SHL Can Offer You Diversity, equity, inclusion and accessibility are key threads in the fabric of SHL’s business and culture (find out more about DEI and accessibility at SHL ) Employee benefits package that takes care of you and your family. Support, coaching, and on-the-job development to achieve career success A fun and flexible workplace where you’ll be inspired to do your best work (find out more LifeAtSHL ) The ability to transform workplaces around the world for others. SHL is an equal opportunity employer. We support and encourage applications from a diverse range of candidates. We can, and do make adjustments to make sure our recruitment process is as inclusive as possible. SHL is an equal opportunity employer.",
        "ICICI Bank Assistant Admin, Experience required 0-2 years, test should be 30-40 mins long",
        "SKEY RESPONSIBITILES: Manage the sound-scape of the station through appropriate creative and marketing interventions to Increase or Maintain the listenership Acts as an interface between Programming & sales team, thereby supporting the sales team by providing creative inputs in order to increase the overall ad spends by clients Build brand Mirchi by ideating fresh programming initiatives on air campaigns, programming led onground events & new properties to ensure brand differentiation & thus increase brand recall at station level Invest time in local RJs to grow & develop them as local celebrities Through strong networking, must focus on identifying the best of local talent and ensure to bring the creative minds from the market on board with Mirchi Build radio as a category for both listeners & advertisers People Management Identifying the right talent and investing time in developing them by frequent feedback on their performance Monitor, Coach and mentor team members on a regular basis Development of Jocks as per guidelines Must have an eye to spot the local talent to fill up vacancies locally TECHNICAL SKILLS & QUALIFICATION REQUIRED: Graduation / Post Graduation (Any specialisation) with 8 -12 years of relevant experience Experience in digital content conceptualisation Strong branding focus Must be well-read in variety of areas and must keep up with the latest events in the city / cluster / country Must know to read, write & speak English PERSONAL ATTRIBUTES: Excellent communication skills Good interpersonal skills People management Suggest me some tests for the above jd. The duration should be at most 90 mins"
    ]

    ground_truth = [
        [
            "Automata - Fix (New)",
            "Core Java (Entry Level) (New)",
            "Java 8 (New)",
            "Core Java (Advanced Level) (New)",
            "Agile Software Development",
            "Technology Professional 8.0 Job Focused Assessment",
            "Computer Science (New)"
        ],
        [
            "Entry level Sales 7.1 (International)",
            "Entry Level Sales Sift Out 7.1",
            "Entry Level Sales Solution",
            "Sales Representative Solution",
            "Sales Support Specialist Solution",
            "Technical Sales Associate Solution",
            "SVAR - Spoken English (Indian Accent) (New)",
            "Sales & Service Phone Solution",
            "Sales & Service Phone Simulation",
            "English Comprehension (New)"
        ],
        [
            "Motivation Questionnaire MQM5",
            "Global Skills Assessment",
            "Graduate 8.0 Job Focused Assessment"
        ],
        [
            "Drupal (New)",
            "Search Engine Optimization (New)",
            "Administrative Professional - Short Form",
            "Entry Level Sales Sift Out 7.1",
            "General Entry Level – Data Entry 7.0 Solution"
        ],
        [
            "Automata Selenium",
            "Automata - Fix (New)",
            "Automata Front End",
            "JavaScript (New)",
            "HTML/CSS (New)",
            "HTML5 (New)",
            "CSS3 (New)",
            "Selenium (New)",
            "SQL Server (New)",
            "Automata - SQL (New)",
            "Manual Testing (New)"
        ],
        [
            "Administrative Professional - Short Form",
            "Verify - Numerical Ability",
            "Financial Professional - Short Form",
            "Bank Administrative Assistant - Short Form",
            "General Entry Level – Data Entry 7.0 Solution",
            "Basic Computer Literacy (Windows 10) (New)",
            "Verify - Verbal Ability - Next Generation",
            "SHL Verify Interactive - Inductive Reasoning",
            "Occupational Personality Questionnaire OPQ32r"
        ],
        [
            "SHL Verify Interactive - Inductive Reasoning",
            "Occupational Personality Questionnaire OPQ32r"
        ]
    ]


    recall_k, map_k = evaluate_model(test_queries, ground_truth)
    print(f"Mean Recall@K: {recall_k:.3f}")
    print(f"Mean MAP@K: {map_k:.3f}")
# Out:
# Mean Recall@K: 0.059
# Mean MAP@K: 0.135

# %%
import json
import numpy as np
import pandas as pd
import gradio as gr
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# ----------------------
# CONSTANTS
# ----------------------

KEY_MAPPING = {
    "A": "Ability & Aptitude",
    "B": "Biodata & Situational Judgement",
    "C": "Competencies",
    "D": "Development & 360",
    "E": "Assessment Exercises",
    "K": "Knowledge & Skills",
    "P": "Personality & Behavior",
    "S": "Simulations"
}

# ----------------------
# LOAD & PREPROCESS DATA
# ----------------------

def load_and_prepare_data(filepath):
    with open(filepath, "r", encoding="utf-8") as f:
        data = json.load(f)

    for item in data:
        item["embedding_text"] = f"{item['name']} {item['description']}"

        try:
            item["duration"] = int(item.get("assessment_length", "0").split('=')[-1].strip())
        except:
            item["duration"] = 0

        item["adaptive_support"] = "Yes" if item.get("adaptive_or_irt") else "No"
        item["remote_support"] = "Yes" if item.get("remote") else "No"

        keys = item.get("keys", [])
        item["test_type"] = [KEY_MAPPING.get(k, k) for k in keys]

        item["job_level"] = (item.get("job_levels") or "").strip().rstrip(",")
        item["languages"] = (item.get("languages") or "").strip().rstrip(",")

        # Add a URL to each assessment (if available in the dataset)
        item["url"] = item.get("url", "No URL available")  # If no URL, assign a placeholder

    return data

assessments = load_and_prepare_data("/content/shl_data_enriched.json")

# ----------------------
# EMBEDDINGS
# ----------------------

model = SentenceTransformer('all-MiniLM-L6-v2')
corpus_embeddings = model.encode([a["embedding_text"] for a in assessments], convert_to_tensor=False)

# ----------------------
# RECOMMENDER
# ----------------------

def recommend_assessments(user_query):
    query_embedding = model.encode(user_query, convert_to_tensor=False)
    similarities = cosine_similarity([query_embedding], corpus_embeddings)[0]
    top_indices = np.argsort(similarities)[::-1][:10]

    results = []
    for i in top_indices:
        a = assessments[i]
        results.append({
            "Assessment Name": a['name'],
            "Job Level": a["job_level"],
            "Duration (min)": a["duration"],
            "Remote Testing": a["remote_support"],
            "Adaptive/IRT": a["adaptive_support"],
            "Test Type(s)": ', '.join(a["test_type"]),
            "Languages": a["languages"],
            "Description": a["description"][:200] + "...",
            "URL": a["link"]  # Include the URL in the result
        })

    return pd.DataFrame(results)

# ----------------------
# GRADIO UI
# ----------------------

demo = gr.Interface(
    fn=recommend_assessments,
    inputs=gr.Textbox(lines=3, label="Enter job description or query"),
    outputs=gr.Dataframe(label="Recommended SHL Assessments"),
    title="🔍 SHL Assessment Recommendation System",
    description="Paste a natural language job query or JD text. The system will recommend the most relevant SHL assessments (up to 10)."
)

# ----------------------
# RUN APP
# ----------------------

if __name__ == "__main__":
    demo.launch(share=True)  # Use share=True to generate public URL
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9f9c78fa70f32f940e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9f9c78fa70f32f940e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from pyngrok import conf
from pyngrok import ngrok
ngrok.kill()
conf.get_default().auth_token = "2wAvyLm35oEfWS97ZpinVeRYms5_2Nv7RqV5is1MegWuaB8d9"

# %%
import json
import re
import numpy as np
from flask import Flask, request, jsonify
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from pyngrok import ngrok
from threading import Thread

KEY_MAPPING = {
    "A": "Ability & Aptitude",
    "B": "Biodata & Situational Judgement",
    "C": "Competencies",
    "D": "Development & 360",
    "E": "Assessment Exercises",
    "K": "Knowledge & Skills",
    "P": "Personality & Behavior",
    "S": "Simulations"
}

# Load and preprocess assessments
with open("shl_data_enriched.json", "r", encoding="utf-8") as f:
    assessments = json.load(f)

for item in assessments:
    item["embedding_text"] = f"{item['name']} {item['description']}"
    try:
        item["duration"] = int(item.get("assessment_length", "0").split('=')[-1].strip())
    except:
        item["duration"] = 0
    item["adaptive_support"] = "Yes" if item.get("adaptive_or_irt") else "No"
    item["remote_support"] = "Yes" if item.get("remote") else "No"
    keys = item.get("keys", [])
    item["test_type"] = [KEY_MAPPING.get(k, k) for k in keys]

    # Ensure URL is present in each assessment (if available)
    item["url"] = item.get("url", "No URL available")  # Provide a default URL if missing

model = SentenceTransformer('sentence-transformers/msmarco-MiniLM-L12-cos-v5')
corpus_embeddings = model.encode([a["embedding_text"] for a in assessments])

def extract_duration_from_query(query):
    match = re.search(r'(\d+)\s*minutes?', query.lower())
    return int(match.group(1)) if match else None

def recommend(query, max_duration=None):
    query_embedding = model.encode(query, convert_to_tensor=False)
    similarities = cosine_similarity([query_embedding], corpus_embeddings)[0]
    top_indices = np.argsort(similarities)[::-1]
    results = []

    for i in top_indices:
        a = assessments[i]
        if max_duration is not None and a.get("duration", 0) > max_duration:
            continue
        results.append({
            "Assessment Name": a.get("name", ""),
            "Job Level": a.get("job_level", "Unknown"),
            "Duration (min)": a.get("duration", 0),
            "Remote Testing": a.get("remote_support", "No"),
            "Adaptive/IRT": a.get("adaptive_support", "No"),
            "Test Type(s)": ', '.join(a.get("test_type", [])),
            "Languages": a.get("languages", "Not specified"),
            "Description": a.get("description", "")[:500],  # Truncate description for brevity
            "URL": a.get("link", "No URL available")  # Include URL in the result
        })
        if len(results) == 10:
            break
    return results

# Flask app
app = Flask(__name__)

@app.route("/shl-ai-apis/recommend", methods=["POST"])
def recommend_endpoint():
    data = request.get_json()
    query = data.get("query", "")
    if not query:
        return jsonify({"error": "Query is required"}), 400
    max_duration = extract_duration_from_query(query)
    recommended_assessments = recommend(query, max_duration)
    return jsonify({"recommended_assessments": recommended_assessments})

@app.route("/shl-ai-apis/health", methods=["GET"])
def health_check():
    return jsonify({"status": "ok"}), 200

# Start Flask app and ngrok in the right order
# Run Flask with ngrok
def run_app():
    app.run(port=5015)  # or any other free port like 5002, 8080, etc.

def start_ngrok():
    public_url = ngrok.connect(5015)
    print(f"🚀 Your public endpoint is: {public_url}")

# Start the Flask app and Ngrok in a thread
Thread(target=run_app).start()  # runs Flask in the background
start_ngrok()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5015
# INFO:werkzeug:Press CTRL+C to quit
# 🚀 Your public endpoint is: NgrokTunnel: "https://f540-35-199-157-109.ngrok-free.app" -> "http://localhost:5015"

# %%
import requests
import json

# Making a GET request to the health endpoint
res = requests.get("https://f540-35-199-157-109.ngrok-free.app/shl-ai-apis/health")
print(res.status_code)
# Pretty print the JSON response from the health check endpoint
print(json.dumps(res.json(), indent=4))

# Query to send in the POST request
query = {
    "query": "I want to hire a content writer who is good at SEO and English"
}

# Making a POST request to the recommend endpoint
res = requests.post("https://f540-35-199-157-109.ngrok-free.app/shl-ai-apis/recommend", json=query)
print(res.status_code)
# Pretty print the JSON response from the recommend endpoint
print(json.dumps(res.json(), indent=4))
# Out:
# INFO:werkzeug:127.0.0.1 - - [09/May/2025 16:24:23] "GET /shl-ai-apis/health HTTP/1.1" 200 -
# 200
# {
#     "status": "ok"
# }
# INFO:werkzeug:127.0.0.1 - - [09/May/2025 16:24:23] "POST /shl-ai-apis/recommend HTTP/1.1" 200 -
# 200
# {
#     "recommended_assessments": [
#         {
#             "Adaptive/IRT": "No",
#             "Assessment Name": "Smart Interview Live",
#             "Description": "SHL Live Video Interview is areal-timevideo interview tool. It allows recruiters and line managers to remotely engage with candidates and reach hiring decisions faster. \r\nDelight shortlisted candidates with a face2face digital interview that goes way beyond a conference call. Interact with whiteboards, instant file-sharing, draw from an expertly-curated question bank and provide a remote end-to-end interview experience that increases your chance of conversion.Language AvailabilityThe Candidate a",
#             "Duration (min)": 0,
#             "Job Level": "Unknown",
#             "Languages": "English (USA),",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Personality & Behavior",
#             "URL": "https://shl.com/products/product-catalog/view/smart-interview-live/"
#         },
#         {
#             "Adaptive/IRT": "No",
#             "Assessment Name": "Smart Interview Live Coding",
#             "Description": "Smart Interview Live Coding is a real-time online coding interview, with a compiler interface. It enables one-to-one, panel and group interviews. Use Smart Interview Live Coding to comprehensively evaluate candidates\u2019 skills across various technical roles and hire the best coding talent.  \r\n \r\nThe language availability for the candidate and interviewer interface is English (US), Simplified Chinese, Castilian Spanish, Japanese. Please note that the questions themselves are available as standard i",
#             "Duration (min)": 0,
#             "Job Level": "Unknown",
#             "Languages": "English (USA),",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Knowledge & Skills",
#             "URL": "https://shl.com/products/product-catalog/view/smart-interview-live-coding/"
#         },
#         {
#             "Adaptive/IRT": "Yes",
#             "Assessment Name": "Professional/Individual Contributor - Short Form",
#             "Description": "The Professional/Individual Contributor solution is for mid to upper-level, non-managerial positions. Sample tasks for these jobs include, but are not limited to: meeting with clients to determine their needs, analyzing data sets, and working with co-workers to complete projects. Potential job titles that use this solution are: Engineer, Human Resource Consultant, and IT Analyst.",
#             "Duration (min)": 44,
#             "Job Level": "Unknown",
#             "Languages": "English (USA),",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Ability & Aptitude, Biodata & Situational Judgement, Personality & Behavior, Simulations",
#             "URL": "https://shl.com/products/product-catalog/view/professionalindividual-contributor-short-form/"
#         },
#         {
#             "Adaptive/IRT": "No",
#             "Assessment Name": "Manager 7.1 (International)",
#             "Description": "Our Manager 7.1 solution is designed for candidates applying to entry-level leadership positions who tend to supervise salaried employees. Sample tasks for these jobs include, but are not limited to: planning projects with subordinates; collaborating with senior managers on developing new methods and procedures; coaching employees on performance-related issues; developing employees ' skills; coordinating activities with other managers to accomplish organizational goals; setting and meeting depar",
#             "Duration (min)": 40,
#             "Job Level": "Unknown",
#             "Languages": "English (USA), English International, French, German, Portuguese (Brazil), Danish, Finnish, Italian, Norwegian, Swedish, Dutch, French (Canada),",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Biodata & Situational Judgement, Competencies, Personality & Behavior",
#             "URL": "https://shl.com/products/product-catalog/view/manager-7-1-solution/"
#         },
#         {
#             "Adaptive/IRT": "No",
#             "Assessment Name": "Professional 7.0 Solution",
#             "Description": "Our Professional 7.0 solution is designed for all non-managerial professional individual contributor positions. Sample tasks for these jobs include, but are not limited to: gathering requirements, analyzing data, managing projects, producing products or services.Report Language Availability:English (USA), Latin American Spanish.",
#             "Duration (min)": 33,
#             "Job Level": "Unknown",
#             "Languages": "English (USA), English International, French (Canada), Latin American Spanish,",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Biodata & Situational Judgement, Competencies",
#             "URL": "https://shl.com/products/product-catalog/view/professional-7-0-solution/"
#         },
#         {
#             "Adaptive/IRT": "No",
#             "Assessment Name": "Professional 7.1 (International)",
#             "Description": "Our Professional 7.1 solution is designed for all non-managerial professional individual contributor positions. Sample tasks for these jobs include, but are not limited to: gathering requirements, analyzing data, managing projects, producing products or services.",
#             "Duration (min)": 33,
#             "Job Level": "Unknown",
#             "Languages": "English International, Swedish, Italian, Finnish, Dutch, French, English (USA), German, Portuguese (Brazil), Latin American Spanish, French (Canada), Danish, Norwegian,",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Competencies, Biodata & Situational Judgement",
#             "URL": "https://shl.com/products/product-catalog/view/professional-7-1-solution-4247/"
#         },
#         {
#             "Adaptive/IRT": "No",
#             "Assessment Name": "Manager 7.1 (Americas)",
#             "Description": "Our Manager 7.1 solution is designed for candidates applying to entry-level leadership positions who tend to supervise salaried employees. Sample tasks for these jobs include, but are not limited to: planning projects with subordinates; collaborating with senior managers on developing new methods and procedures; coaching employees on performance-related issues; developing employees ' skills; coordinating activities with other managers to accomplish organizational goals; setting and meeting depar",
#             "Duration (min)": 40,
#             "Job Level": "Unknown",
#             "Languages": "Portuguese (Brazil), French (Canada),",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Biodata & Situational Judgement, Competencies, Personality & Behavior",
#             "URL": "https://shl.com/products/product-catalog/view/manager-7-1-%28americas%29/"
#         },
#         {
#             "Adaptive/IRT": "No",
#             "Assessment Name": "Smart Interview On Demand",
#             "Description": "Smart Interview On Demand is arecorded(asynchronous) video interview tool, that introduces you to each person behind the resume with a short-recorded video of them explaining why they would be an awesome addition to your team. A streamlined, minimum bias screening to ensure you shortlist top talent faster and find those hidden gems you may have otherwise missed.   \r\nAvailability Theadministrator and evaluator interfaceis available in US English and Simplified Chinese only, as are the standard qu",
#             "Duration (min)": 0,
#             "Job Level": "Unknown",
#             "Languages": "English (USA), Chinese Simplified,",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Personality & Behavior",
#             "URL": "https://shl.com/products/product-catalog/view/smart-interview-on-demand/"
#         },
#         {
#             "Adaptive/IRT": "Yes",
#             "Assessment Name": "Sales Professional Solution",
#             "Description": "The Sales Professional solution is for entry to mid-level sales positions in which employees proactively sell products to customers, develop relationships with repeat customers, and have their pay and/or performance heavily based on sales revenue. Sample tasks for these jobs include, but are not limited to: promoting products to customers, persuading customers to buy products, and building ongoing customer relationships.\r\nPotential job titles that use this solution are: Sales Consultant, Sales R",
#             "Duration (min)": 47,
#             "Job Level": "Unknown",
#             "Languages": "English (USA),",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Ability & Aptitude, Biodata & Situational Judgement, Personality & Behavior",
#             "URL": "https://shl.com/products/product-catalog/view/sales-professional-solution/"
#         },
#         {
#             "Adaptive/IRT": "Yes",
#             "Assessment Name": "Manager + 7.1 (International)",
#             "Description": "Our Manager + 7.1 solution is designed for candidates applying to entry-level leadership positions who tend to supervise salaried employees, and includes SHL\u2019s new innovative mobile-first ability assessment, Verify Interactive \u2013 Deductive Reasoning. Sample tasks for these jobs include, but are not limited to: planning projects with subordinates; collaborating with senior managers on developing new methods and procedures; coaching employees on performance-related issues; developing employees ' sk",
#             "Duration (min)": 63,
#             "Job Level": "Unknown",
#             "Languages": "French (Canada), Dutch, Finnish, Norwegian, Swedish, Portuguese (Brazil), Danish, English (USA), Italian,",
#             "Remote Testing": "Yes",
#             "Test Type(s)": "Biodata & Situational Judgement, Competencies, Personality & Behavior",
#             "URL": "https://shl.com/products/product-catalog/view/manager-7-1-%28international%29/"
#         }
#     ]
# }
